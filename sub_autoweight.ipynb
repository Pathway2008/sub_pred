# %% [markdown]
# <a href="https://colab.research.google.com/github/Pathway2008/sub_pred/blob/main/sub_autoweight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
info = pd.read_csv('/content/drive/MyDrive/predict_subcribe/data_info.csv')
sub = pd.read_csv('/content/drive/MyDrive/predict_subcribe/sample_submission.csv')
train = pd.read_csv('/content/drive/MyDrive/predict_subcribe/train.csv')
test = pd.read_csv('/content/drive/MyDrive/predict_subcribe/test.csv')

# %%
info
# Out:
#                                column  \
# 0                             user_id
# 1               subscription_duration
# 2                   recent_login_time
# 3                  average_login_time
# 4   average_time_per_learning_session
# 5        monthly_active_learning_days
# 6             total_completed_courses
# 7         recent_learning_achievement
# 8         abandoned_learning_sessions
# 9          community_engagement_level
# 10         preferred_difficulty_level
# 11                  subscription_type
# 12           customer_inquiry_history
# 13                    payment_pattern
# 14                             target
#
#                                           description
# 0                                         사용자의 고유 식별자
# 1                                사용자가 서비스에 가입한 기간 (월)
# 2                              사용자가 마지막으로 로그인한 시간 (일)
# 3                                    사용자의 일반적인 로그인 시간
# 4                              각 학습 세션에 소요된 평균 시간 (분)
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labels = [col for col in train.columns if train[col].dtype == 'object' and col not in ['user_id']]
label_encoders = {}
for col in labels:
    label_encoders[col] = LabelEncoder()
    train[col] = label_encoders[col].fit_transform(train[col])
    test[col] = label_encoders[col].transform(test[col])

# %%
test.drop(['user_id'],axis=1,inplace=True)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
k=5
X = test
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=42)

# %%
test['group'] = kmeans.labels_

# %%
group_summary1 = test.groupby('group')['subscription_duration','recent_login_time',].describe()
group_summary2 = test.groupby('group')['average_login_time','average_time_per_learning_session',].describe()
group_summary3 = test.groupby('group')['monthly_active_learning_days','total_completed_courses',].describe()
group_summary4 = test.groupby('group')['recent_learning_achievement','abandoned_learning_sessions',].describe()
group_summary5 = test.groupby('group')['community_engagement_level','preferred_difficulty_level',].describe()
group_summary6 = test.groupby('group')['subscription_type','customer_inquiry_history',].describe()
group_summary7 = test.groupby('group')['payment_pattern',].describe()


display(group_summary1)
display(group_summary2)
display(group_summary3)
display(group_summary4)
display(group_summary5)
display(group_summary6)
display(group_summary7)
# Out:
# <ipython-input-112-a0f08e92f5b4>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group_summary1 = test.groupby('group')['subscription_duration','recent_login_time',].describe()
# <ipython-input-112-a0f08e92f5b4>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group_summary2 = test.groupby('group')['average_login_time','average_time_per_learning_session',].describe()
# <ipython-input-112-a0f08e92f5b4>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group_summary3 = test.groupby('group')['monthly_active_learning_days','total_completed_courses',].describe()
# <ipython-input-112-a0f08e92f5b4>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...

# %%
train[train['abandoned_learning_sessions']==0]['target'].describe()
# Out:
# count    464.000000
# mean       0.629310
# std        0.483511
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
train[train['monthly_active_learning_days']>=22]['target'].describe()
# Out:
# count    1260.000000
# mean        0.645238
# std         0.478631
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
train[train['total_completed_courses']==19]['target'].describe()
# Out:
# count    190.000000
# mean       0.631579
# std        0.483651
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
train[(train['monthly_active_learning_days']>=22) & (train['total_completed_courses']>15) & (train['total_completed_courses']<20) ]['target'].describe()
# Out:
# count    198.000000
# mean       0.651515
# std        0.477698
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
train[train['community_engagement_level']==5]['target'].describe()
# Out:
# count    4564.000000
# mean        0.628177
# std         0.483344
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
train[(train['community_engagement_level']==5) & (train['abandoned_learning_sessions']<=1)]['target'].describe()
# Out:
# count    864.000000
# mean       0.637731
# std        0.480934
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
train[train['abandoned_learning_sessions']<=1]['target'].describe()
# Out:
# count    1949.000000
# mean        0.641355
# std         0.479726
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
train['abandoned_learning_sessions'].describe()
# Out:
# count    10000.000000
# mean         3.043600
# std          1.755052
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         12.000000
# Name: abandoned_learning_sessions, dtype: float64

# %%
train['abandoned_learning_sessions'].value_counts()
# Out:
# 2     2226
# 3     2195
# 4     1704
# 1     1485
# 5     1026
# 6      530
# 0      464
# 7      237
# 8       91
# 9       27
# 10       9
# 11       4
# 12       2
# Name: abandoned_learning_sessions, dtype: int64

# %%
train['average_time_per_learning_session'].describe()
# Out:
# count    10000.000000
# mean        54.917720
# std         56.024310
# min          0.011515
# 25%         15.276611
# 50%         37.578818
# 75%         75.584200
# max        503.372616
# Name: average_time_per_learning_session, dtype: float64

# %%
train[train['average_time_per_learning_session']>75]['target'].describe()
# Out:
# count    2524.000000
# mean        0.675119
# std         0.468423
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
train['average_time_per_learning_session'].describe()
# Out:
# count    10000.000000
# mean        54.917720
# std         56.024310
# min          0.011515
# 25%         15.276611
# 50%         37.578818
# 75%         75.584200
# max        503.372616
# Name: average_time_per_learning_session, dtype: float64

# %%
train['average_time_per_learning_session'].quantile(.15)
# Out:
# 8.692340575797436

# %%
train['average_time_per_learning_session'].quantile(.85)
# Out:
# 103.79202815728432

# %%
train[(train['average_time_per_learning_session'] > 103) & (train['abandoned_learning_sessions']<=3)]['target'].describe()
# Out:
# count    960.000000
# mean       0.728125
# std        0.445158
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
train[(train['abandoned_learning_sessions'] >=4 ) & (train['average_time_per_learning_session']<9)]['target'].describe()
# Out:
# count    574.000000
# mean       0.578397
# std        0.494246
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %% [markdown]
# # Passionate

# %%
train['passionate'] = 0
train.loc[(train['average_time_per_learning_session'] > 75) & (train['abandoned_learning_sessions'] <= 3), 'passionate'] = 1

train['uninterest'] = 0
train.loc[(train['abandoned_learning_sessions']>=5) & (train['average_time_per_learning_session']< 37), 'uninterest'] = 1

# %%
train[(train['average_time_per_learning_session']>75) & (train['abandoned_learning_sessions']<=3)]['target'].describe()
# Out:
# count    1601.000000
# mean        0.680200
# std         0.466545
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
exam = train[(train['average_time_per_learning_session']>75) & (train['abandoned_learning_sessions']<=3)].reset_index(drop=True)

# %%
numeric_columns1 = ['passionate','uninterest']
summary_stats1 = train.groupby('target')[numeric_columns1].agg(['mean', 'std', 'median'])

display(summary_stats1)
# Out:
#        passionate                  uninterest
#              mean       std median       mean       std median
# target
# 0        0.134701  0.341449    0.0   0.109708  0.312567    0.0
# 1        0.175673  0.380573    0.0   0.089853  0.285994    0.0

# %%
# H0: mean is same
from scipy.stats import ttest_ind

t_test_results = pd.DataFrame(index=numeric_columns1, columns=['t_statistic', 'p_value'])

for column in numeric_columns1:
    subscribed = train[train['target'] == 1][column]
    not_subscribed = train[train['target'] == 0][column]
    t_stat, p_value = ttest_ind(subscribed, not_subscribed)

    t_test_results.loc[column, 't_statistic'] = t_stat
    t_test_results.loc[column, 'p_value'] = p_value

t_test_results
# Out:
#            t_statistic  p_value
# passionate    5.431062      0.0
# uninterest   -3.251873  0.00115

# %%
from scipy.stats import chi2_contingency

# The null hypothesis cannot be rejected
for column in numeric_columns1:
    cont_table = pd.crosstab(train[column], train['target'])

    chi2_stat, p_value, dof, expected = chi2_contingency(cont_table)

    print(column)
    print(f"Chi2 Statistic: {chi2_stat}")
    print(f"P-value: {p_value}")
    print(f"Degrees of Freedom: {dof}")
    print("Expected Frequencies Table:")
    print(expected)
    print('---------------------------------------------------------')
# Out:
# passionate
# Chi2 Statistic: 29.111647775339478
# P-value: 6.832496815415309e-08
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[3192.4599 5206.5401]
#  [ 608.5401  992.4599]]
# ---------------------------------------------------------
# uninterest
# Chi2 Statistic: 10.340980145821533
# P-value: 0.0013010890512780916
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[3430.7826 5595.2174]
#  [ 370.2174  603.7826]]
# ---------------------------------------------------------

# %%
filtered_data = train[train['average_time_per_learning_session'] > 120]
grouped_data = filtered_data.groupby('abandoned_learning_sessions')['target'].describe().reset_index()

grouped_data
# Out:
#     abandoned_learning_sessions  count      mean       std  min   25%  50%  \
# 0                             0   53.0  0.735849  0.445099  0.0  0.00  1.0
# 1                             1  184.0  0.771739  0.420857  0.0  1.00  1.0
# 2                             2  248.0  0.766129  0.424147  0.0  1.00  1.0
# 3                             3  224.0  0.785714  0.411245  0.0  1.00  1.0
# 4                             4  205.0  0.775610  0.418201  0.0  1.00  1.0
# 5                             5  106.0  0.783019  0.414148  0.0  1.00  1.0
# 6                             6   68.0  0.735294  0.444457  0.0  0.00  1.0
# 7                             7   29.0  0.862069  0.350931  0.0  1.00  1.0
# 8                             8    8.0  0.875000  0.353553  0.0  1.00  1.0
# 9                             9    2.0  0.500000  0.707107  0.0  0.25  0.5
# 10                           12    1.0  1.000000       NaN  1.0  1.00  1.0
#
#      75%  max
# 0   1.00  1.0
# 1   1.00  1.0
# 2   1.00  1.0
# ...

# %%
for sessions in range(7, -1, -1):
    filtered_data = train[(train['average_time_per_learning_session'] > 80) & (train['abandoned_learning_sessions'] <= sessions)]['target']
    print(f"Abandoned Sessions <= {sessions}:")
    print(filtered_data.describe())

# %%
train[train['abandoned_learning_sessions']>=5]['target'].describe()
# Out:
# count    1926.000000
# mean        0.606957
# std         0.488553
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
train[train['average_time_per_learning_session'] < 37]['target'].describe()
# Out:
# count    4954.000000
# mean        0.598506
# std         0.490250
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %% [markdown]
# # uninterest

# %%
train[(train['abandoned_learning_sessions']>=5) & (train['average_time_per_learning_session']< 37)]['target'].describe()
# Out:
# count    974.000000
# mean       0.571869
# std        0.495062
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64
